# %%
# %pip install sklearn.preprocessing
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2n/8mc_gc0j7_b8xfff_rzhf5740000gn/T/pip-install-ttzc0g_q/sklearn_0748a5283cd941d3a3cb6b5297eb34fe/setup.py'"'"'; __file__='"'"'/private/var/folders/2n/8mc_gc0j7_b8xfff_rzhf5740000gn/T/pip-install-ttzc0g_q/sklearn_0748a5283cd941d3a3cb6b5297eb34fe/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2n/8mc_gc0j7_b8xfff_rzhf5740000gn/T/pip-pip-egg-info-ebh3vwhx
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df=pd.read_csv("Telefon turini aniqlash 2.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2000 non-null   int64
#  1   blutus                         2000 non-null   int64
#  2   protsessor_tezligi             2000 non-null   float64
#  3   ikkita simkartalik             2000 non-null   int64
#  4   Oldi_kamera                    2000 non-null   int64
#  5   4G                             2000 non-null   int64
#  6   Ichki_xotira                   2000 non-null   int64
#  7   tel_ingichgaligi               1997 non-null   float64
#  8   Rangi                          2000 non-null   object
#  9   Vazni                          2000 non-null   int64
#  10  Protsessor yadrolari soni      1999 non-null   float64
#  11  Asosiy kamera                  1998 non-null   float64
# ...

# %%
#1. Drop rows with missing values

df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1987 entries, 0 to 1999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                1987 non-null   int64
#  1   blutus                         1987 non-null   int64
#  2   protsessor_tezligi             1987 non-null   float64
#  3   ikkita simkartalik             1987 non-null   int64
#  4   Oldi_kamera                    1987 non-null   int64
#  5   4G                             1987 non-null   int64
#  6   Ichki_xotira                   1987 non-null   int64
#  7   tel_ingichgaligi               1987 non-null   float64
#  8   Rangi                          1987 non-null   object
#  9   Vazni                          1987 non-null   int64
#  10  Protsessor yadrolari soni      1987 non-null   float64
#  11  Asosiy kamera                  1987 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        0
# Asosiy kamera                    0
# Qurilma xajmi(pix)               0
# Qurilma ekran kengligi(pix)      0
# ram                              0
# Qurilma xajmi(cm)                0
# Qurilma ekran kengligi(cm)       0
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
#2. Drop columns with missing values

df.dropna(axis=1, inplace=True)

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.fillna(df.mean(), inplace=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# ...

# %%
df["Rangi"].value_counts()
# Out:
# Rangi
# Qora         1989
# Yashil          6
# Oq              2
# Qizil           1
# Jigarrang       1
# Sariq           1
# Name: count, dtype: int64

# %%
df.fillna(0, inplace=True)  #df.fillna(fixed value, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2000 non-null   int64
#  1   blutus                         2000 non-null   int64
#  2   protsessor_tezligi             2000 non-null   float64
#  3   ikkita simkartalik             2000 non-null   int64
#  4   Oldi_kamera                    2000 non-null   int64
#  5   4G                             2000 non-null   int64
#  6   Ichki_xotira                   2000 non-null   int64
#  7   tel_ingichgaligi               2000 non-null   float64
#  8   Rangi                          2000 non-null   object
#  9   Vazni                          2000 non-null   int64
#  10  Protsessor yadrolari soni      2000 non-null   float64
#  11  Asosiy kamera                  2000 non-null   float64
# ...

# %%
label_encoder=LabelEncoder() #call qilamiz
df["Rangi"] = label_encoder.fit_transform(df["Rangi"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2000 non-null   int64
#  1   blutus                         2000 non-null   int64
#  2   protsessor_tezligi             2000 non-null   float64
#  3   ikkita simkartalik             2000 non-null   int64
#  4   Oldi_kamera                    2000 non-null   int64
#  5   4G                             2000 non-null   int64
#  6   Ichki_xotira                   2000 non-null   int64
#  7   tel_ingichgaligi               1997 non-null   float64
#  8   Rangi                          2000 non-null   int64
#  9   Vazni                          2000 non-null   int64
#  10  Protsessor yadrolari soni      1999 non-null   float64
#  11  Asosiy kamera                  1998 non-null   float64
# ...

# %%
df["Rangi"]
# Out:
# 0       2
# 1       5
# 2       4
# 3       0
# 4       1
#        ..
# 1995    3
# 1996    3
# 1997    3
# 1998    3
# 1999    3
# Name: Rangi, Length: 2000, dtype: int64

# %%
df["Rangi"].value_counts()
# Out:
# Rangi
# 3    1989
# 5       6
# 1       2
# 2       1
# 0       1
# 4       1
# Name: count, dtype: int64

# %%
df_encoded=pd.get_dummies(df, columns=["Rangi"], drop_first=False)

# %%
df_encoded
# Out:
#       battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0                 842       0                 2.2                   0
# 1                1021       1                 0.5                   1
# 2                 563       1                 0.5                   1
# 3                 615       1                 2.5                   0
# 4                1821       1                 1.2                   0
# ...               ...     ...                 ...                 ...
# 1995              794       1                 0.5                   1
# 1996             1965       1                 2.6                   1
# 1997             1911       0                 0.9                   1
# 1998             1512       0                 0.9                   0
# 1999              510       1                 2.0                   1
#
#       Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi  Vazni  \
# 0               1   0             7               0.6    188
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2000 non-null   int64
#  1   blutus                         2000 non-null   int64
#  2   protsessor_tezligi             2000 non-null   float64
#  3   ikkita simkartalik             2000 non-null   int64
#  4   Oldi_kamera                    2000 non-null   int64
#  5   4G                             2000 non-null   int64
#  6   Ichki_xotira                   2000 non-null   int64
#  7   tel_ingichgaligi               1997 non-null   float64
#  8   Vazni                          2000 non-null   int64
#  9   Protsessor yadrolari soni      1999 non-null   float64
#  10  Asosiy kamera                  1998 non-null   float64
#  11  Qurilma xajmi(pix)             1998 non-null   float64
# ...

# %%
df_encoded.fillna(0).astype(int)
# Out:
#       battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0                 842       0                   2                   0
# 1                1021       1                   0                   1
# 2                 563       1                   0                   1
# 3                 615       1                   2                   0
# 4                1821       1                   1                   0
# ...               ...     ...                 ...                 ...
# 1995              794       1                   0                   1
# 1996             1965       1                   2                   1
# 1997             1911       0                   0                   1
# 1998             1512       0                   0                   0
# 1999              510       1                   2                   1
#
#       Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi  Vazni  \
# 0               1   0             7                 0    188
# ...

# %% [markdown]
# #Uyga Vazifa

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df=pd.read_csv("Corporate Stress.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                50000 non-null  int64
#  1   Age                               50000 non-null  int64
#  2   Gender                            50000 non-null  object
#  3   Marital_Status                    50000 non-null  object
#  4   Job_Role                          49999 non-null  object
#  5   Experience_Years                  50000 non-null  int64
#  6   Monthly_Salary_INR                50000 non-null  float64
#  7   Working_Hours_per_Week            50000 non-null  int64
#  8   Commute_Time_Hours                49999 non-null  float64
#  9   Remote_Work                       50000 non-null  bool
#  10  Stress_Level                      49999 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                                      0
# Age                                     0
# Gender                                  0
# Marital_Status                          0
# Job_Role                                1
# Experience_Years                        0
# Monthly_Salary_INR                      0
# Working_Hours_per_Week                  0
# Commute_Time_Hours                      1
# Remote_Work                             0
# Stress_Level                            1
# Health_Issues                       12541
# Company_Size                            0
# Department                              0
# Sleep_Hours                             0
# Physical_Activity_Hours_per_Week        0
# Mental_Health_Leave_Taken               1
# Manager_Support_Level                   0
# Work_Pressure_Level                     1
# Annual_Leaves_Taken                     1
# Work_Life_Balance                       2
# Family_Support_Level                    0
# ...

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37452 entries, 2 to 49999
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                37452 non-null  int64
#  1   Age                               37452 non-null  int64
#  2   Gender                            37452 non-null  object
#  3   Marital_Status                    37452 non-null  object
#  4   Job_Role                          37452 non-null  object
#  5   Experience_Years                  37452 non-null  int64
#  6   Monthly_Salary_INR                37452 non-null  float64
#  7   Working_Hours_per_Week            37452 non-null  int64
#  8   Commute_Time_Hours                37452 non-null  float64
#  9   Remote_Work                       37452 non-null  bool
#  10  Stress_Level                      37452 non-null  float64
# ...

# %%
df.dropna(axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                50000 non-null  int64
#  1   Age                               50000 non-null  int64
#  2   Gender                            50000 non-null  object
#  3   Marital_Status                    50000 non-null  object
#  4   Experience_Years                  50000 non-null  int64
#  5   Monthly_Salary_INR                50000 non-null  float64
#  6   Working_Hours_per_Week            50000 non-null  int64
#  7   Remote_Work                       50000 non-null  bool
#  8   Company_Size                      50000 non-null  object
#  9   Department                        50000 non-null  object
#  10  Sleep_Hours                       50000 non-null  float64
# ...

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[3], line 1
#
# ----> 1 df.fillna(df.mean(), inplace=True)
#
#
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
#   11685 @doc(make_doc("mean", ndim=2))
#
#   11686 def mean(
#
#   11687     self,
#
#    (...)
#
#   11691     **kwargs,
#
#   11692 ):
#
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#
#   11694     if isinstance(result, Series):
#
#   11695         result = result.__finalize__(self, method="mean")
#
#
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
#   12413 def mean(
#
#   12414     self,
#
#   12415     axis: Axis | None = 0,
#
#    (...)
#
#   12418     **kwargs,
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                50000 non-null  int64
#  1   Age                               50000 non-null  int64
#  2   Gender                            50000 non-null  object
#  3   Marital_Status                    50000 non-null  object
#  4   Job_Role                          49999 non-null  object
#  5   Experience_Years                  50000 non-null  int64
#  6   Monthly_Salary_INR                50000 non-null  float64
#  7   Working_Hours_per_Week            50000 non-null  int64
#  8   Commute_Time_Hours                49999 non-null  float64
#  9   Remote_Work                       50000 non-null  bool
#  10  Stress_Level                      49999 non-null  float64
# ...

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female        16769
# Male          16718
# Non-Binary    16513
# Name: count, dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                50000 non-null  int64
#  1   Age                               50000 non-null  int64
#  2   Gender                            50000 non-null  object
#  3   Marital_Status                    50000 non-null  object
#  4   Job_Role                          50000 non-null  object
#  5   Experience_Years                  50000 non-null  int64
#  6   Monthly_Salary_INR                50000 non-null  float64
#  7   Working_Hours_per_Week            50000 non-null  int64
#  8   Commute_Time_Hours                50000 non-null  float64
#  9   Remote_Work                       50000 non-null  bool
#  10  Stress_Level                      50000 non-null  float64
# ...

# %%
cat_cols=df.select_dtypes(include=["object", "category"]).columns.tolist()

# %%
cat_cols
# Out:
# ['Gender',
#  'Marital_Status',
#  'Job_Role',
#  'Health_Issues',
#  'Company_Size',
#  'Department',
#  'Mental_Health_Leave_Taken',
#  'Burnout_Symptoms',
#  'Location']

# %%
label=LabelEncoder()
df['Gender'] = label.fit_transform(df['Gender'])

# %%
print(df['Job_Role'].unique())
# Out:
# ['Developer' 'Analyst' 'Sales' 'Manager' 'HR' 'Support' 0]

# %%
df['Job_Role'] = df['Job_Role'].astype(str)
df['Job_Role'] = label.fit_transform(df['Job_Role'])

# %%
df['Health_Issues'] = df['Health_Issues'].astype(str)
df['Health_Issues'] = label.fit_transform(df['Health_Issues'])

# %%
df['Company_Size'] = label.fit_transform(df['Company_Size'])
df['Department'] = label.fit_transform(df['Department'])
df['Burnout_Symptoms'] = label.fit_transform(df['Burnout_Symptoms'])
df['Location'] = label.fit_transform(df['Location'])

# %%
df['Mental_Health_Leave_Taken'] = df['Mental_Health_Leave_Taken'].astype(str)
df['Mental_Health_Leave_Taken'] = label.fit_transform(df['Mental_Health_Leave_Taken'])

# %%
cat_cols=df.select_dtypes(include=["object", "category"]).columns.tolist()

# %%
cat_cols
# Out:
# ['Gender',
#  'Marital_Status',
#  'Job_Role',
#  'Health_Issues',
#  'Company_Size',
#  'Department',
#  'Mental_Health_Leave_Taken',
#  'Burnout_Symptoms',
#  'Location']

# %%
df['Marital_Status'] = label.fit_transform(df['Marital_Status'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                50000 non-null  int64
#  1   Age                               50000 non-null  int64
#  2   Gender                            50000 non-null  int64
#  3   Marital_Status                    50000 non-null  int64
#  4   Job_Role                          50000 non-null  int64
#  5   Experience_Years                  50000 non-null  int64
#  6   Monthly_Salary_INR                50000 non-null  float64
#  7   Working_Hours_per_Week            50000 non-null  int64
#  8   Commute_Time_Hours                50000 non-null  float64
#  9   Remote_Work                       50000 non-null  bool
#  10  Stress_Level                      50000 non-null  float64
# ...

# %%
df_encoded=pd.get_dummies(df, columns=['Gender'], drop_first=False)

# %%
df_encoded=pd.get_dummies(df, columns=['Marital_Status'], drop_first=False)

# %%
df_encoded=pd.get_dummies(df, columns=['Job_Role'], drop_first=False)

# %%
df_encoded=pd.get_dummies(df, columns=['Health_Issues'], drop_first=False)

# %%
df_encoded.astype(int)
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[8], line 1
#
# ----> 1 df_encoded.astype(int)
#
#
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#
#    6637     results = [
#
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#
#    6639     ]
#
#    6641 else:
#
#    6642     # else, only a single dtype is given
#
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#
#    6645     return res.__finalize__(self, method="astype")
#
#
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#
#     427 elif using_copy_on_write():
#
# ...
