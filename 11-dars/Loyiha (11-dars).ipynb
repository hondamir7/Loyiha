# %% [markdown]
# # Linear vs Decision Tree

# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv('Airplane Services.csv')

# %%
df.head()
# Out:
#    id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   1    Male  disloyal Customer   48  Business travel  Business
# 1   2  Female     Loyal Customer   35  Business travel  Business
# 2   3    Male     Loyal Customer   41  Business travel  Business
# 3   4    Male     Loyal Customer   50  Business travel  Business
# 4   5  Female     Loyal Customer   49  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              821                      3                                  3
# 1              821                      2                                  2
# 2              853                      4                                  4
# 3             1905                      2                                  2
# 4             3470                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       3  ...                       5                 3
# 1                       2  ...                       5                 5
# 2                       4  ...                       3                 3
# 3                       2  ...                       5                 5
# 4                       3  ...                       3                 3
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 2                 5                4                 5
# 1                 5                 5                3                 5
# 2                 3                 3                4                 3
# 3                 5                 5                3                 5
# 4                 4                 3                3                 3
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                           2                       5.0
# 1            5                          26                      39.0
# 2            5                           0                       0.0
# 3            4                           0                       0.0
# 4            5                           0                       1.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1                satisfied
# 2                satisfied
# 3                satisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 50000 non-null  int64
#  1   Gender                             50000 non-null  object
#  2   Customer Type                      50000 non-null  object
#  3   Age                                50000 non-null  int64
#  4   Type of Travel                     50000 non-null  object
#  5   Class                              50000 non-null  object
#  6   Flight Distance                    50000 non-null  int64
#  7   Inflight wifi service              50000 non-null  int64
#  8   Departure/Arrival time convenient  50000 non-null  int64
#  9   Ease of Online booking             50000 non-null  int64
#  10  Gate location                      50000 non-null  int64
#  11  Food and drink                     50000 non-null  int64
#  12  Online boarding                    50000 non-null  int64
#  13  Seat comfort                       50000 non-null  int64
#  14  Inflight entertainment             50000 non-null  int64
#  15  On-board service                   50000 non-null  int64
#  16  Leg room service                   50000 non-null  int64
#  17  Baggage handling                   50000 non-null  int64
#  18  Checkin service                    50000 non-null  int64
#  19  Inflight service                   50000 non-null  int64
#  20  Cleanliness                        50000 non-null  int64
#  21  Departure Delay in Minutes         50000 non-null  int64
#  22  Arrival Delay in Minutes           49842 non-null  float64
#  23  satisfaction                       50000 non-null  object
# dtypes: float64(1), int64(18), object(5)
# memory usage: 9.2+ MB

# %%
df.fillna(df["Arrival Delay in Minutes"].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# ENCODING

# %%
cardinality=df.nunique()

# %%
cardinality
# Out:
# id                                   50000
# Gender                                   2
# Customer Type                            2
# Age                                     75
# Type of Travel                           2
# Class                                    3
# Flight Distance                       3462
# Inflight wifi service                    6
# Departure/Arrival time convenient        6
# Ease of Online booking                   6
# Gate location                            5
# Food and drink                           6
# Online boarding                          6
# Seat comfort                             6
# Inflight entertainment                   6
# On-board service                         6
# Leg room service                         6
# Baggage handling                         5
# Checkin service                          6
# Inflight service                         6
# Cleanliness                              6
# Departure Delay in Minutes             394
# Arrival Delay in Minutes               403
# satisfaction                             2
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype=='object':
        if cardinality[col]<=5:
            df=pd.get_dummies(df,columns=[col],dtype=int,drop_first=True)
        else:
            le=LabelEncoder()
            df[col]=le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 50000 non-null  int64
#  1   Age                                50000 non-null  int64
#  2   Flight Distance                    50000 non-null  int64
#  3   Inflight wifi service              50000 non-null  int64
#  4   Departure/Arrival time convenient  50000 non-null  int64
#  5   Ease of Online booking             50000 non-null  int64
#  6   Gate location                      50000 non-null  int64
#  7   Food and drink                     50000 non-null  int64
#  8   Online boarding                    50000 non-null  int64
#  9   Seat comfort                       50000 non-null  int64
#  10  Inflight entertainment             50000 non-null  int64
#  11  On-board service                   50000 non-null  int64
#  12  Leg room service                   50000 non-null  int64
#  13  Baggage handling                   50000 non-null  int64
#  14  Checkin service                    50000 non-null  int64
#  15  Inflight service                   50000 non-null  int64
#  16  Cleanliness                        50000 non-null  int64
#  17  Departure Delay in Minutes         50000 non-null  int64
#  18  Arrival Delay in Minutes           50000 non-null  float64
#  19  Gender_Male                        50000 non-null  int64
#  20  Customer Type_disloyal Customer    50000 non-null  int64
#  21  Type of Travel_Personal Travel     50000 non-null  int64
#  22  Class_Eco                          50000 non-null  int64
#  23  Class_Eco Plus                     50000 non-null  int64
#  24  satisfaction_satisfied             50000 non-null  int64
# dtypes: float64(1), int64(24)
# memory usage: 9.5 MB

# %%
num_col=df.select_dtypes(include=['int64','int32']).columns

# %%
num_col
# Out:
# Index(['id', 'Age', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Gender_Male',
#        'Customer Type_disloyal Customer', 'Type of Travel_Personal Travel',
#        'Class_Eco', 'Class_Eco Plus', 'satisfaction_satisfied'],
#       dtype='object')

# %% [markdown]
# SCALING

# %%
scaler=StandardScaler()
df[num_col]=scaler.fit_transform(df[num_col])

# %%
df.head()
# Out:
#          id       Age  Flight Distance  Inflight wifi service  \
# 0 -1.531676  0.555757        -0.353414               0.208014
# 1 -1.531641 -0.302937        -0.353414              -0.544461
# 2 -1.531605  0.093384        -0.321954               0.960490
# 3 -1.531569  0.687864         0.712321              -0.544461
# 4 -1.531534  0.621811         2.250953               0.208014
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                          -0.039917                0.171882       0.015807
# 1                          -0.695150               -0.537493      -0.763640
# 2                           0.615316                0.881257       0.795254
# 3                          -0.695150               -0.537493      -0.763640
# 4                          -0.039917                0.171882       0.015807
#
#    Food and drink  Online boarding  Seat comfort  ...  Inflight service  \
# 0        1.353673        -0.187497      1.181918  ...          1.144312
# 1       -0.150859         1.292005      0.424463  ...          1.144312
# 2        1.353673         1.292005      1.181918  ...         -0.562954
# 3        0.601407         0.552254      1.181918  ...          1.144312
# 4        0.601407         1.292005      0.424463  ...         -0.562954
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0     1.304820                   -0.320342                       5.0
# 1     1.304820                    0.253340                      39.0
# 2     1.304820                   -0.368149                       0.0
# 3     0.543992                   -0.368149                       0.0
# 4     1.304820                   -0.368149                       1.0
#
#    Gender_Male  Customer Type_disloyal Customer  \
# 0     1.009001                         2.117607
# 1    -0.991080                        -0.472231
# 2     1.009001                        -0.472231
# 3     1.009001                        -0.472231
# 4    -0.991080                        -0.472231
#
#    Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                       -0.667211  -0.886261       -0.273972
# 1                       -0.667211  -0.886261       -0.273972
# 2                       -0.667211  -0.886261       -0.273972
# 3                       -0.667211  -0.886261       -0.273972
# 4                       -0.667211  -0.886261       -0.273972
#
#    satisfaction_satisfied
# 0               -0.874878
# 1                1.143016
# 2                1.143016
# 3                1.143016
# 4                1.143016
#
# [5 rows x 25 columns]

# %%
x=df.drop(columns=['satisfaction_satisfied'])

# %%
y=df['satisfaction_satisfied']

# %%
x_train,x_temp,y_train,y_temp=train_test_split(x,y,test_size=0.2,random_state=42)
x_test,x_val,y_test,y_val=train_test_split(x_temp,y_temp,test_size=0.5,random_state=42)

# %%
x_train.shape
# Out:
# (40000, 24)

# %%
y_train.shape
# Out:
# (40000,)

# %%
x_test.shape
# Out:
# (5000, 24)

# %%
y_test.shape
# Out:
# (5000,)

# %%
x_val.shape
# Out:
# (5000, 24)

# %%
y_val.shape
# Out:
# (5000,)

# %%
#Model Selection
model=LinearRegression()

# %%
linear_model=model.fit(x_train,y_train)

# %%
linear_model
# Out:
# LinearRegression()

# %%
y_pred=linear_model.predict(x_test)

# %%
y_pred
# Out:
# array([-0.15314972, -0.18260451, -0.92279661, ...,  0.50310077,
#        -0.86506587,  1.0022026 ], shape=(5000,))

# %%
y
# Out:
# 0       -0.874878
# 1        1.143016
# 2        1.143016
# 3        1.143016
# 4        1.143016
#            ...
# 49995    1.143016
# 49996   -0.874878
# 49997   -0.874878
# 49998   -0.874878
# 49999   -0.874878
# Name: satisfaction_satisfied, Length: 50000, dtype: float64

# %%
mse_linear=mean_squared_error(y_test,y_pred)
r2_linear=r2_score(y_test,y_pred)

# %%
print(mse_linear)
print(r2_linear)
# Out:
# 0.4242832870453284
# 0.5757258927344959

# %% [markdown]
# DECISION TREE

# %%
model=DecisionTreeRegressor()

# %%
model
# Out:
# DecisionTreeRegressor()

# %%
dt_model=model.fit(x_train,y_train)

# %%
dt_model
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt_model.predict(x_test)

# %%
y_pred
# Out:
# array([-0.8748783 , -0.8748783 , -0.8748783 , ..., -0.8748783 ,
#        -0.8748783 ,  1.14301611], shape=(5000,))

# %%
y[:5]
# Out:
# 0   -0.874878
# 1    1.143016
# 2    1.143016
# 3    1.143016
# 4    1.143016
# Name: satisfaction_satisfied, dtype: float64

# %%
mse_tree=mean_squared_error(y_test,y_pred)
r2_tree=r2_score(y_test,y_pred)

# %%
print(mse_tree)
print(r2_tree)
# Out:
# 0.2410563548126467
# 0.7589488606750474

# %%
print(mse_tree)
print(r2_tree)
print(mse_linear)
print(r2_linear)
# Out:
# 0.2410563548126467
# 0.7589488606750474
# 0.4242832870453284
# 0.5757258927344959

# %%
print(mse_tree)
print(r2_tree)
print(mse_linear)
print(r2_linear)
# Out:
# 0.2410563548126467
# 0.7589488606750474
# 0.4242832870453284
# 0.5757258927344959
